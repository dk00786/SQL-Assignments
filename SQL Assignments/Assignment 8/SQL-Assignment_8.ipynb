# %% [markdown]
# ## SQL-Assignment_8

# %% [markdown]
# ### Q-15. Write an SQL query to fetch intersecting records of two tables.

# %% [markdown]
#     select
#         worker.empno,
#         worker.first_name,
#         workerclone.empno,
#         workerclone.first_name
#     from worker
#     inner join workerclone
#     on workerclone.name = worker.name

# %% [markdown]
# ![A8_1.JPG](attachment:A8_1.JPG)

# %% [markdown]
# ### Q-16. Write an SQL query to show records from one table that another table does not have.

# %% [markdown]
#     SELECT w.empno,  w.first_name , wc.empno,  wc.first_name
#     FROM workerclone w
#     LEFT JOIN worker wc
#     ON w.first_name = wc.first_name;

# %% [markdown]
# ![A8_2.JPG](attachment:A8_2.JPG)

# %% [markdown]
# ## THE END
