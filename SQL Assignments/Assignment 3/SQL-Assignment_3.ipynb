# %% [markdown]
# ## SQL-Assignment_3

# %% [markdown]
# ### Q-1. Write an SQL query to print the FIRST_NAME from Worker table after removing white spaces from the right side

# %% [markdown]
# #### SELECT RTRIM(FIRST_NAME) FROM worker;

# %% [markdown]
# ![A3_1.JPG](attachment:A3_1.JPG)

# %% [markdown]
# ### Q-2. Write an SQL query that fetches the unique values of DEPARTMENT from Worker table and prints its length.

# %% [markdown]
# #### SELECT DISTINCT DEPARTMENT, LENGTH(DEPARTMENT) AS departmentNameLength FROM worker;

# %% [markdown]
# ![A3_2.JPG](attachment:A3_2.JPG)

# %% [markdown]
# ### Q-3. Write an SQL query to fetch nth max salaries from a table.

# %% [markdown]
# #### SELECT Salary FROM Worker ORDER BY Salary DESC LIMIT 5,1;
# where n = 5

# %% [markdown]
# ![A3_3.JPG](attachment:A3_3.JPG)

# %% [markdown]
# ## THE END
